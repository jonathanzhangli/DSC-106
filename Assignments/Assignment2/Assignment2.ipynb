# %%
import pandas as pd

# %%
df = pd.read_csv("E-commerce data.csv")

# %%
df
# Out:
#       Row ID       Ship Mode Customer ID      Segment           City  \
# 0        849  Standard Class    GA-14725     Consumer         Lorain
# 1       4010  Standard Class    SC-20725     Consumer    Los Angeles
# 2       6683     First Class    DP-13390  Home Office       Franklin
# 3       8070  Standard Class    JM-15250     Consumer     Huntsville
# 4       8071  Standard Class    JM-15250     Consumer     Huntsville
# ...      ...             ...         ...          ...            ...
# 3307     908  Standard Class    PO-18865     Consumer  New York City
# 3308     909  Standard Class    PO-18865     Consumer  New York City
# 3309    1297  Standard Class    EB-13975    Corporate      Fairfield
# 3310    1298  Standard Class    EB-13975    Corporate      Fairfield
# 3311    5092  Standard Class    JM-15580     Consumer       Loveland
#
#            State  Postal Code   Region         Category Sub-Category    Sales  \
# ...

# %%
sums = df.groupby('State')['Sales'].sum()

# %%
top3 = df.groupby('State')['Sales'].sum().sort_values(ascending=False)[0:3].index
top3
# Out:
# Index(['California', 'New York', 'Washington'], dtype='object', name='State')

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
value_list = ['California', 'New York', 'Washington']
boolean_series = df['State'].isin(value_list)
filtered_df = df[boolean_series]
filtered_df
# Out:
#       Row ID       Ship Mode Customer ID    Segment              City  \
# 1       4010  Standard Class    SC-20725   Consumer       Los Angeles
# 17      9686    Second Class    FW-14395  Corporate       Los Angeles
# 18      5258  Standard Class    DL-13315   Consumer  Rancho Cucamonga
# 19      9491  Standard Class    CM-12385   Consumer     San Francisco
# 20      9492  Standard Class    CM-12385   Consumer     San Francisco
# ...      ...             ...         ...        ...               ...
# 3306     907  Standard Class    PO-18865   Consumer     New York City
# 3307     908  Standard Class    PO-18865   Consumer     New York City
# 3308     909  Standard Class    PO-18865   Consumer     New York City
# 3309    1297  Standard Class    EB-13975  Corporate         Fairfield
# 3310    1298  Standard Class    EB-13975  Corporate         Fairfield
#
#            State  Postal Code Region         Category Sub-Category     Sales  \
# ...

# %%
categories = filtered_df.groupby('Category')['Sales'].sum()
categories
# Out:
# Category
# Furniture           82834.8915
# Office Supplies     99134.5240
# Technology         123881.8200
# Name: Sales, dtype: float64

# %%
filtered_df = filtered_df[filtered_df['Category'] == 'Technology']
filtered_df
# Out:
#       Row ID       Ship Mode Customer ID      Segment           City  \
# 17      9686    Second Class    FW-14395    Corporate    Los Angeles
# 79      1659  Standard Class    TH-21100     Consumer    Los Angeles
# 81      2409  Standard Class    TM-21010     Consumer  San Francisco
# 85       734  Standard Class    DS-13030  Home Office        Seattle
# 108     6360  Standard Class    CS-12250    Corporate        Seattle
# ...      ...             ...         ...          ...            ...
# 3206    8178     First Class    CM-12115     Consumer    Los Angeles
# 3237    4620     First Class    RM-19675  Home Office    Los Angeles
# 3278     574  Standard Class    JF-15415     Consumer  New York City
# 3294    1879  Standard Class    JG-15160     Consumer    Los Angeles
# 3307     908  Standard Class    PO-18865     Consumer  New York City
#
#            State  Postal Code Region    Category Sub-Category     Sales  \
# ...

# %%
subcats = filtered_df.groupby('Sub-Category')['Sales'].sum()
subcats
# Out:
# Sub-Category
# Accessories    27441.120
# Copiers        37659.694
# Machines       22972.746
# Phones         35808.260
# Name: Sales, dtype: float64

# %%
quantity_df = df[df['Region'] == "East"]
quantity_df
# Out:
#       Row ID       Ship Mode Customer ID      Segment           City  \
# 0        849  Standard Class    GA-14725     Consumer         Lorain
# 29      7221  Standard Class    BP-11290     Consumer   Philadelphia
# 30      1846    Second Class    DA-13450  Home Office     Washington
# 31      1847    Second Class    DA-13450  Home Office     Washington
# 56      2767     First Class    RW-19690     Consumer   Philadelphia
# ...      ...             ...         ...          ...            ...
# 3278     574  Standard Class    JF-15415     Consumer  New York City
# 3295    2875     First Class    MC-17845     Consumer  New York City
# 3306     907  Standard Class    PO-18865     Consumer  New York City
# 3307     908  Standard Class    PO-18865     Consumer  New York City
# 3308     909  Standard Class    PO-18865     Consumer  New York City
#
#                      State  Postal Code Region         Category Sub-Category  \
# ...

# %%
quantity_df['Quantity'].unique()
# Out:
# array([ 4,  3,  6,  2,  1,  8,  9,  5,  7, 14, 10, 11, 13, 12])

# %%
quantity_df['Discount'].unique()
# Out:
# array([0.2, 0.7, 0. , 0.4, 0.3, 0.1, 0.5])

# %%
df['Region'].unique()
# Out:
# array(['East', 'West', 'Central', 'South'], dtype=object)
